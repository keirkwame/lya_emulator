# %%
import copy as cp
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import fake_spectra.spectra as fss
# Out:
# /share/apps/anaconda/python3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
spectra_instance = fss.Spectra(10, '/home/keir/Data/nCDM', None, None,
                               savefile='lya_forest_spectra_1.00.hdf5')
# Out:
# 32000  sightlines. resolution:  1.0001795880652051  z= 4.24

# %%
spectra_instance.vmax * (1. + spectra_instance.red) / 3.e+5
# Out:
# 0.02281556333382983

# %%
optical_depth = cp.deepcopy(spectra_instance.get_tau('H', 1, 1215))
optical_depth.shape
# Out:
# (32000, 1306)

# %%
optical_depth_rolling = cp.deepcopy(spectra_instance.get_tau('H', 1, 1215, add_z_evolution=True))
optical_depth_rolling.shape
# Out:
# tau_scale = 0.6606453219486867
# Original mean flux = 0.26830722308147553
# i, tau_scale = 0 0.619292277249095
# i, tau_scale = 1 0.7770167063576432
# i, tau_scale = 2 0.6733854988546015
# i, tau_scale = 3 0.7634065010571843
# i, tau_scale = 4 0.8519245281526564
# i, tau_scale = 5 1.0232390747680793
# i, tau_scale = 6 0.6480723649566005
# i, tau_scale = 7 0.33875932562947164
# i, tau_scale = 8 0.46031148160499225
# i, tau_scale = 9 0.5781228317893352
# New mean flux = 0.3479585571365616
# (32000, 1306)

# %%
idx = 100
plt.plot(np.exp(-1. * optical_depth[idx] * 0.6603893498381546), label='Original')
plt.plot(np.exp(-1. * optical_depth_rolling[idx]), label='Corrected')
plt.legend()

# %%
type(1388 // 10)
